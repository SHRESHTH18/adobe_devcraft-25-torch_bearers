# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Reading bid files

# %%
file_paths=['/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.06.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.07.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.08.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.09.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.10.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.11.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/bid.12.txt']
df_list=[]
for file in file_paths:
    df = pd.read_csv(file, header=None,sep='\t')  # Read file without headers
    df_list.append(df)

# Combine all DataFrames into a single DataFrame
final_bid_df = pd.concat(df_list, ignore_index=True)

# Assign your own column names
final_bid_df.columns = ["BidID","Timestamp","VisitorID","User-Agent","IP","Region",
                   "City","Adexchange","Domain","URL","AnonymousURLID","AdslotID",
                   "Adslotwidth","Adslotheight",'Adslotvisibility',"Adslotformat",
                   "Adslotfloorprice","CreativeID","Biddingprice","AdvertiserID","User_profile_tags"]
# Out:
# /var/folders/g6/xlpbbym16z53sw8j543bt30m0000gn/T/ipykernel_47550/2992595872.py:10: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None,sep='\t')  # Read file without headers
# /var/folders/g6/xlpbbym16z53sw8j543bt30m0000gn/T/ipykernel_47550/2992595872.py:10: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None,sep='\t')  # Read file without headers
# /var/folders/g6/xlpbbym16z53sw8j543bt30m0000gn/T/ipykernel_47550/2992595872.py:10: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, header=None,sep='\t')  # Read file without headers
# /var/folders/g6/xlpbbym16z53sw8j543bt30m0000gn/T/ipykernel_47550/2992595872.py:10: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
bid_df=final_bid_df

# %%
unique_counts=filtered_columns

# %% [markdown]
# # Reading imp files

# %%
# file_paths=['/kaggle/input/user-data/Dataset/imp_06.csv',
#            '/kaggle/input/user-data/Dataset/imp_07.csv',
#            '/kaggle/input/user-data/Dataset/imp_08.csv',
#            '/kaggle/input/user-data/Dataset/imp_09.csv',
#            '/kaggle/input/user-data/Dataset/imp_10.csv',
#            '/kaggle/input/user-data/Dataset/imp_11.csv',
#            '/kaggle/input/user-data/Dataset/imp_12.csv']

file_paths=['/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.06.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.07.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.08.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.09.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.10.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.11.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/imp.12.txt']
df_list=[]
for file in file_paths:
    df = pd.read_csv(file, header=None,sep='\t')  # Read file without headers
#     df = pd.read_csv(file)
    df_list.append(df)

# Combine all DataFrames into a single DataFrame
final_imp_df = pd.concat(df_list, ignore_index=True)

# Assign your own column names
final_imp_df.columns = ["BidID","Timestamp","Logtype","VisitorID","User-Agent","IP","Region",
                   "City","Adexchange","Domain","URL","AnonymousURLID","AdslotID",
                   "Adslotwidth","Adslotheight",'Adslotvisibility',"Adslotformat",
                   "Adslotfloorprice","CreativeID","Biddingprice","Payingprice","KeypageURL"
                    ,"AdvertiserID","User_profile_tags"]  # Change as needed

imp_df=final_imp_df

# %%
imp_df=final_imp_df

# %% [markdown]
# # Reading clk files

# %%
# file_paths=['/kaggle/input/user-data/Dataset/clk_06.csv',
#            '/kaggle/input/user-data/Dataset/clk_07.csv',
#            '/kaggle/input/user-data/Dataset/clk_08.csv',
#            '/kaggle/input/user-data/Dataset/clk_09.csv',
#            '/kaggle/input/user-data/Dataset/clk_10.csv',
#            '/kaggle/input/user-data/Dataset/clk_11.csv',
#            '/kaggle/input/user-data/Dataset/clk_12.csv']

file_paths=['/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.06.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.07.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.08.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.09.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.10.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.11.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/clk.12.txt']

df_list = []
for file in file_paths:
    df = pd.read_csv(file, header=None, sep='\t')  # Read file without headers
#     df = pd.read_csv(file)
    df_list.append(df)

# Combine all DataFrames into a single DataFrame
final_clk_df = pd.concat(df_list, ignore_index=True)

# Assign your own column names
final_clk_df.columns = ["BidID", "Timestamp", "Logtype", "VisitorID", "User-Agent", "IP", "Region",
                   "City", "Adexchange", "Domain", "URL", "AnonymousURLID", "AdslotID",
                   "Adslotwidth", "Adslotheight", "Adslotvisibility", "Adslotformat",
                   "Adslotfloorprice", "CreativeID", "Biddingprice", "Payingprice", "KeypageURL",
                   "AdvertiserID", "User_profile_tags"]  # Change as needed

clk_df = final_clk_df

# %%
clk_df = final_clk_df

# %% [markdown]
# # Reading conv files

# %%
# file_paths=['/kaggle/input/user-data/Dataset/conv_06.csv',
#            '/kaggle/input/user-data/Dataset/conv_07.csv',
#            '/kaggle/input/user-data/Dataset/conv_08.csv',
#            '/kaggle/input/user-data/Dataset/conv_09.csv',
#            '/kaggle/input/user-data/Dataset/conv_10.csv',
#            '/kaggle/input/user-data/Dataset/conv_11.csv',
#            '/kaggle/input/user-data/Dataset/conv_12.csv']

file_paths=['/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.06.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.07.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.08.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.09.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.10.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.11.txt',
           '/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset/conv.12.txt']

df_list = []
for file in file_paths:
    df = pd.read_csv(file, header=None, sep='\t')  #for txt file
#     df = pd.read_csv(file)  # Read file without headers
    df_list.append(df)

# Combine all DataFrames into a single DataFrame
final_conv_df = pd.concat(df_list, ignore_index=True)

# Assign your own column names
final_conv_df.columns = ["BidID", "Timestamp", "Logtype", "VisitorID", "User-Agent", "IP", "Region",
                   "City", "Adexchange", "Domain", "URL", "AnonymousURLID", "AdslotID",
                   "Adslotwidth", "Adslotheight", "Adslotvisibility", "Adslotformat",
                   "Adslotfloorprice", "CreativeID", "Biddingprice", "Payingprice", "KeypageURL",
                   "AdvertiserID", "User_profile_tags"]  # Change as needed

# %%
conv_df = final_conv_df

# %% [markdown]
# # imp_list -> list of BidIDs of all rows of imp_df

# %%
# bid_list = bid_df['BidID'].to_list()
imp_list = imp_df['BidID'].to_list()
clk_list = clk_df['BidID'].to_list()
conv_list = conv_df['BidID'].to_list()
L1, L2, L3 = [], [], []

# %% [markdown]
# # creating an is_click column in imp_df

# %%
clk_set = set(clk_list)
L2 = [1 if imp in clk_set else 0 for imp in imp_list]

# %%
print(len(imp_df),len(L2),len(imp_list))
# Out:
# 12237087 12237087 12237087

# %%
imp_df['is_clk'] = L2

# %%
imp_df_with_isclk= imp_df

# %% [markdown]
# # creating as is_conv column in imp_df

# %%
conv_set = set(conv_list)
L3 = [1 if clk in conv_set else 0 for clk in clk_list]

# %%
clk_df['is_conv'] = L3

# %%
print(len(clk_df),len(clk_list),len(L3))
# Out:
# 9978 9978 9978

# %% [markdown]
# # Data preprocessing
#
# BidID           - drop
#
# Timestamp       - extract hours then drop
#
# Logtype        - all same values we just get to know which file it is (  imp-1 , clk -2 , conv-3)
# VisitorID      - DROP as unique values
#
# User-Agent     - extract browser and OS using parsing and then drop
#
# IP             - drop as unique values
#
# Region         - 35 values - Label encode
#
# City          - DROP as correlation between region and city is 0.99
#
# Adexchange    - one hot encode
#
# Domain        - drop as we cannot get nay information
#
# URL           - drop as high number of unique values
#
# AnonymousURLID - drop as all values are NAN
#
# AdslotID      - dropping for now(many unique values) maybe use later
#
# Adslotwidth   - drop as area= width *height
#
# Adslotheight  - drop as area= width *height
#
# Adslotarea   - create area=height*width
#
# Adslotvisibility - one hot encode only 4 values
#
# Adslotformat     - one hot encode as 3 values (important)
#
# Adslotfloorprice - keep as numerical column
#
# CreativeID - 74 values LabelEncode
#
# Biddingprice - drop as no use
#
# Payingprice - drop as no use
#
# KeypageURL - 18 values LabelEncode
#
# AdvertiserID  - one hot encode as only 5 advertisers
#
# User_profile_tags  -  drop after multilabel binarising

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer , StandardScaler, OneHotEncoder , LabelEncoder ,OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # encoding user_profile_tags using multi label binariser

# %%
def encoding_user_profile_tags(df):
    df['tags_list'] = df['User_profile_tags'].fillna("NaN").str.split(',')
    df.head()
    mlb = MultiLabelBinarizer()
    tags = mlb.fit_transform(df['tags_list'])
    profile_tags_df = pd.DataFrame(tags, columns=mlb.classes_, index=df.index)
    df_final = pd.concat([df, profile_tags_df], axis=1)
    df = df_final
    df.drop('tags_list', axis=1, inplace=True)
    df.drop('User_profile_tags',axis=1,inplace=True)
    return df

# %%
imp_df.shape
# Out:
# (12237087, 26)

# %%
imp_df=encoding_user_profile_tags(imp_df)

# %%
imp_df.shape
# Out:
# (12237087, 68)

# %% [markdown]
# # making a new column hours from timestamp

# %%
def extracting_hours(df):
    df['Timestamp'] = pd.to_datetime(df['Timestamp'].astype(str).str[:14], format='%Y%m%d%H%M%S')
    df['Hours'] = df['Timestamp'].dt.hour 
    df.drop('Timestamp',axis=1,inplace=True)
    return df

# %%
imp_df=extracting_hours(imp_df)

# %%
imp_df.shape
# Out:
# (12237087, 68)

# %% [markdown]
# # Providing column(that we get from multilabelbinariser) mappings and extracting os and browser from user-agent

# %%
column_mapping = {
    10006: "interest_news",
    10024: "interest_education",
    10031: "interest_automobile",
    10048: "interest_real_estate",
    10052: "interest_IT",
    10057: "interest_electronic_game",
    10059: "interest_fashion",
    10063: "interest_entertainment",
    10067: "interest_luxury",
    10074: "interest_home_and_lifestyle",
    10075: "interest_health",
    10076: "interest_food",
    10077: "interest_divine",
    10079: "interest_motherhood_parenting",
    10083: "interest_sports",
    10093: "interest_travel_outdoors",
    10102: "interest_social",
    10684: "Inmarket_3c_product",
    11092: "Inmarket_appliances",
    11278: "Inmarket_clothing_shoes_bags",
    11379: "Inmarket_Beauty_Personal_Care",
    11423: "Inmarket_household_home_improvement",
    11512: "Inmarket_infant_mom_products",
    11576: "Inmarket_sports_item",
    11632: "Inmarket_outdoor",
    11680: "Inmarket_health_care_products",
    11724: "Inmarket_luxury",
    11944: "Inmarket_real_estate",
    13042: "Inmarket_automobile",
    13403: "Inmarket_finance",
    13496: "Inmarket_travel",
    13678: "Inmarket_education",
    13776: "Inmarket_service",
    13800: "interest_art_photography_design",
    13866: "interest_online_literature",
    13874: "Inmarket_electronic_game",
    14273: "interest_3c",
    16593: "Inmarket_book",
    16617: "Inmarket_medicine",
    16661: "Inmarket_food_drink",
    16706: "interest_culture",
    16751: "interest_sex",
    10110: "Demographic_gender_male"
}

def map_browser(agent):
    browsers = ['edge', 'trident', 'chrome', 'firefox', 'safari', 'opera']
    for browser in browsers:
        if browser in agent.lower():
            return browser
    return 'other'

def map_os(agent):
    os_list = ['windows', 'linux', 'mac os x']
    for os in os_list:
        if os in agent.lower():
            return os
    return 'other'
    
def apply_mappings(df):
    df['OS'] = df['User-Agent'].astype(str).apply(map_os)
    df['Browser'] = df['User-Agent'].astype(str).apply(map_browser)
    df.drop(['User-Agent'],axis=1,inplace=True)
    df.rename(columns={str(k): v for k, v in column_mapping.items()}, inplace=True)
    return df

# %%
imp_df=apply_mappings(imp_df)

# %%
imp_df.shape
# Out:
# (12237087, 69)

# %% [markdown]
# # creating a column area=width*height

# %%
def ad_area(df):
    df['Adslotarea']=df['Adslotheight']*df['Adslotwidth']
    df.drop(['Adslotheight'],axis=1,inplace=True)
    df.drop(['Adslotwidth'],axis=1,inplace=True)
    return df

# %%
imp_df=ad_area(imp_df)

# %%
imp_df.shape
# Out:
# (12237087, 68)

# %% [markdown]
# # dropping columns with very high number of unique values
# ### 10111-demographic/female   -> redundant as demographic/male already exists

# %%
drop_cols=['BidID','Logtype','VisitorID','IP','City','Domain','URL',
          'AnonymousURLID','AdslotID',
          'Biddingprice','Payingprice','10111']

# %%
def drop_columns(df):
    return df.drop(columns=drop_cols, axis=1,inplace=True)  # Return a new DataFrame instead of modifying inplace
drop_columns(imp_df)

# %%
imp_df.shape
# Out:
# (12237087, 56)

# %% [markdown]
# ## Scaling the numerical columns
# ## OneHotEncode the columns with less no. of unique values
# ## LabelEncode with high no. of unique values

# %%
# num_cols=['Hours','Adslotarea','Adslotfloorprice']
label_encode_cols=['Region','CreativeID','KeypageURL']
one_hot_cols=['Adexchange','Adslotvisibility','Adslotformat','AdvertiserID','OS','Browser']
columns_to_scale=['Adslotarea','Adslotfloorprice']

# %%
scaler=StandardScaler()
imp_df[columns_to_scale] = scaler.fit_transform(imp_df[columns_to_scale])

# %%
imp_df_without_ohe = imp_df

# %%
imp_df.shape
# Out:
# (12237087, 56)

# %%
one_hot_encoder=OneHotEncoder(handle_unknown='ignore',sparse=False)

one_hot_encoded_array = one_hot_encoder.fit_transform(imp_df[one_hot_cols])

encoded_df = pd.DataFrame(one_hot_encoded_array)

imp_df.drop(columns=one_hot_cols, axis=1,inplace=True)

imp_df = pd.concat([imp_df, encoded_df], axis=1)
# Out:
# /Users/shreshthgarg/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
imp_df.shape
# Out:
# (12237087, 75)

# %%
imp_df_with_ohe = imp_df

# %%
label_encoders = {}

# Apply LabelEncoder to each column
for col in label_encode_cols:
    le = LabelEncoder()
    imp_df[col] = le.fit_transform(imp_df[col])  # Transform the column
    label_encoders[col] = le  # Store encoder if needed later

# %%
imp_df.shape
# Out:
# (12237087, 75)

# %% [markdown]
# # saving the csv file

# %%
imp_df.to_csv('/Users/shreshthgarg/Desktop/hackathons/adobe devcraft \'25/dataset modified/preprocessed_imp/imp_modified.csv')
